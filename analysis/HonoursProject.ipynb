# %%
from google.colab import drive
drive.mount('/content/drive')
# %ls
# %cd drive/
# %ls
# %cd My\ Drive
# %ls
# !pwd

import pandas as pd
# Out:
# Mounted at /content/drive
# drive/  sample_data/
# /content/drive
# MyDrive/
# /content/drive/My Drive
# 'Colab Notebooks'/   data/
# /content/drive/My Drive

# %%
dataset = pd.read_csv('data/honoursproject/standstill.csv', names=['x', 'y', 'z'])

dataset.shape
dataset.head()
# Out:
#           x         y         z
# 0 -0.011964  0.038764  1.971207
# 1 -0.024885  0.078006  3.945286
# 2 -0.034935  0.119163  5.920322
# 3 -0.046899  0.159841  7.896793
# 4 -0.061735  0.200040  9.877572

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(dataset.index, dataset['x'])
plt.plot(dataset.index, dataset['y'])
plt.plot(dataset.index, dataset['z'])

plt.xlabel('Reading index')
plt.ylabel('Acceleration (ms/s)')

# Show the plot
plt.show()
